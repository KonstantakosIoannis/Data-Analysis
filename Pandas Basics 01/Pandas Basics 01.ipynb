# %%
import pandas
import numpy

# %%
a=['cat','dog','crocodile','elephant']

# %%
a
# Out:
# ['cat', 'dog', 'crocodile', 'elephant']

# %%
aSerie = pandas.Series(a)

# %%
aSerie
#index inserted and type=object instead of string
# Out:
# 0          cat
# 1          dog
# 2    crocodile
# 3     elephant
# dtype: object

# %%
b=[('cat',10),('dog',12),('crocodile',4),('elephant',9)]

# %%
bDataFrame = pandas.DataFrame(b)

# %%
bDataFrame
# Out:
#            0   1
# 0        cat  10
# 1        dog  12
# 2  crocodile   4
# 3   elephant   9

# %%
cDataFrame = pandas.DataFrame(b,columns=['animal','age'])#column names

# %%
cDataFrame
# Out:
#       animal  age
# 0        cat   10
# 1        dog   12
# 2  crocodile    4
# 3   elephant    9

# %%
cDataFrame['age']  #Series
# Out:
# 0    10
# 1    12
# 2     4
# 3     9
# Name: age, dtype: int64

# %%
type(cDataFrame['age'])
# Out:
# pandas.core.series.Series

# %%
cDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   animal  4 non-null      object
#  1   age     4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
cDataFrame.dtypes#.info is better
# Out:
# animal    object
# age        int64
# dtype: object

# %%
myData01 = pandas.read_csv('MrBeast_youtube_stats.csv')

# %%
myData01.head()  #() not necessary
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2021-04-24 20:00:00+00:00  youtube#video               861   84717282.0
# 1  2021-12-18 21:00:00+00:00  youtube#video               729   32090178.0
# ...

# %%
myData01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     246 non-null    object
#  1   title                                  247 non-null    object
#  2   description                            247 non-null    object
#  3   publishTime                            247 non-null    object
#  4   kind_stats                             246 non-null    object
#  5   duration_seconds                       247 non-null    int64
#  6   viewCount                              246 non-null    float64
#  7   likeCount                              244 non-null    float64
#  8   commentCount                           245 non-null    float64
#  9   thumbnails.default.url                 247 non-null    object
# ...

# %%
myData01.describe()  #only for numeric columns
# Out:
#        duration_seconds     viewCount     likeCount   commentCount  \
# count        247.000000  2.460000e+02  2.440000e+02     245.000000
# mean        1886.234818  5.084638e+07  1.610498e+06   75562.783673
# std         8642.188728  4.062672e+07  1.879529e+06   85356.537127
# min            0.000000  1.395400e+04  3.700000e+02      59.000000
# 25%          425.500000  1.406442e+07  4.348780e+05   21552.000000
# 50%          776.000000  4.904782e+07  1.358232e+06   60701.000000
# 75%          923.000000  8.125392e+07  2.294378e+06   99670.000000
# max        85686.000000  1.787632e+08  1.904943e+07  726861.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                     246.0                      246.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %%
myData01.iloc[4]
# Out:
# id                                                                             cExLQ1o2pDw
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# ...

# %%
myData01.loc[4]
# Out:
# id                                                                             cExLQ1o2pDw
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# ...

# %%
myData01.set_index('id')
#instead of the default index now i have column('id') as the index
#SOS this is temporary if i want to effect permenent the dataframe:
#mydata01=mydata01.setindex....
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
myData01=myData01.set_index('id')

# %%
myData01
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
myData01.iloc[4]
# Out:
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# thumbnails.default.width                                                             120.0
# ...

# %%
myData01.loc['cExLQ1o2pDw']
# Out:
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# thumbnails.default.width                                                             120.0
# ...

# %%
myData01.columns
# Out:
# Index(['title', 'description', 'publishTime', 'kind_stats', 'duration_seconds',
#        'viewCount', 'likeCount', 'commentCount', 'thumbnails.default.url',
#        'thumbnails.default.width', 'thumbnails.default.height',
#        'thumbnails.medium.url', 'thumbnails.medium.width',
#        'thumbnails.medium.height', 'thumbnails.high.url',
#        'thumbnails.high.width', 'thumbnails.high.height',
#        'contentDetails.duration', 'contentDetails.dimension',
#        'topicDetails.topicCategories', 'snippet.defaultLanguage',
#        'localizations.en.title', 'localizations.en.description',
#        'snippet.tags', 'contentDetails.contentRating.ytRating'],
#       dtype='object')

# %%
adf=myData01[['title', 'description', 'publishTime', 'kind_stats', 'duration_seconds',
       'viewCount', 'likeCount', 'commentCount']]

# %%
adf
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf.shape
# Out:
# (247, 8)

# %%
adf['viewCount']>1000000 #Boolean Serie
# Out:
# id
# TQHEJj68Jew     True
# 00NgUctWoLQ     True
# NaN            False
# ayXxwJJId_c     True
# cExLQ1o2pDw     True
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
adf[adf['viewCount']>1000000]
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf.loc[adf['viewCount']>1000000]#same as above
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf.query('viewCount>1000000')#same
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf.isna()
# Out:
#              title  description  publishTime  kind_stats  duration_seconds  \
# id
# TQHEJj68Jew  False        False        False       False             False
# 00NgUctWoLQ  False        False        False       False             False
# NaN          False        False        False        True             False
# ayXxwJJId_c  False        False        False       False             False
# cExLQ1o2pDw  False        False        False       False             False
# ...            ...          ...          ...         ...               ...
# yeHjsYQ076A  False        False        False       False             False
# X7doE4h6W64  False        False        False       False             False
# AIytwdufwW8  False        False        False       False             False
# 56OkH6ocYZU  False        False        False       False             False
# zi7tZ-2PhLk  False        False        False       False             False
#
#              viewCount  likeCount  commentCount
# id
# ...

# %%
adf['viewCount'].isna()
# Out:
# id
# TQHEJj68Jew    False
# 00NgUctWoLQ    False
# NaN             True
# ayXxwJJId_c    False
# cExLQ1o2pDw    False
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
adf.dropna(subset=['viewCount'])
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf[adf['viewCount'].isna()] #only null values
# Out:
#        title                                        description  \
# id
# NaN  MrBeast  Accomplishments - Raised $20000000 To Plant 20...
#
#                    publishTime kind_stats  duration_seconds  viewCount  \
# id
# NaN  2012-02-20 00:43:50+00:00        NaN                 0        NaN
#
#      likeCount  commentCount
# id
# NaN        NaN           NaN

# %%
adf[~adf['viewCount'].isna()] #NOT null values
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf=adf.dropna(subset=['viewCount'])

# %%
adf['viewCount'].astype('int') #change the type from float to int
# Out:
# id
# TQHEJj68Jew     84717282
# 00NgUctWoLQ     32090178
# ayXxwJJId_c    101745632
# cExLQ1o2pDw     50008942
# GLoeAJUcz38    145527042
#                  ...
# yeHjsYQ076A        16312
# X7doE4h6W64        15740
# AIytwdufwW8        18502
# 56OkH6ocYZU        16627
# zi7tZ-2PhLk        18773
# Name: viewCount, Length: 246, dtype: int32

# %% [markdown]
# PROSOXI SOS. otan se mia numeric stili exw null values prepei i stili na einai FLOAT
# Afou tis kanw drop meta ti metatrepw se INT

# %%
adf['viewCount']=adf['viewCount'].astype('int')

# %%
adf['publishTime']#type=object=string BUT dates should by date-typed
# Out:
# id
# TQHEJj68Jew    2021-04-24 20:00:00+00:00
# 00NgUctWoLQ    2021-12-18 21:00:00+00:00
# ayXxwJJId_c    2021-04-03 20:00:01+00:00
# cExLQ1o2pDw    2021-09-26 20:00:06+00:00
# GLoeAJUcz38    2020-11-14 21:00:02+00:00
#                          ...
# yeHjsYQ076A    2015-04-26 21:26:36+00:00
# X7doE4h6W64    2015-06-21 12:22:34+00:00
# AIytwdufwW8    2015-05-29 20:07:48+00:00
# 56OkH6ocYZU    2015-05-15 16:48:54+00:00
# zi7tZ-2PhLk    2015-05-31 18:31:25+00:00
# Name: publishTime, Length: 246, dtype: object

# %%
pandas.to_datetime(adf['publishTime'])
# Out:
# id
# TQHEJj68Jew   2021-04-24 20:00:00+00:00
# 00NgUctWoLQ   2021-12-18 21:00:00+00:00
# ayXxwJJId_c   2021-04-03 20:00:01+00:00
# cExLQ1o2pDw   2021-09-26 20:00:06+00:00
# GLoeAJUcz38   2020-11-14 21:00:02+00:00
#                          ...
# yeHjsYQ076A   2015-04-26 21:26:36+00:00
# X7doE4h6W64   2015-06-21 12:22:34+00:00
# AIytwdufwW8   2015-05-29 20:07:48+00:00
# 56OkH6ocYZU   2015-05-15 16:48:54+00:00
# zi7tZ-2PhLk   2015-05-31 18:31:25+00:00
# Name: publishTime, Length: 246, dtype: datetime64[ns, UTC]

# %% [markdown]
# Tonumeric is another function that makes the type equal to int float or whaterver pandas
# desides by itsefl. automatic transormation based on the values.

# %%
adf['rate']=adf['likeCount']/adf['viewCount']
# Out:
# C:\Users\konst\AppData\Local\Temp\ipykernel_2560\524883737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adf['rate']=adf['likeCount']/adf['viewCount']

# %%
adf
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
pandas.concat([adf,myData01])
#the second dataframe is placed below the first one
#we should be carefull to have the same columns otherwise 
#we will have a lot of NULL
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %% [markdown]
# PLOTS

# %%
adf['viewCount'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#for example : there less than 10 videos that have over 1.500.000 views
#and 70 videos that have 0-250.000 views

# %%
adf[adf['viewCount']>1500000]
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
adf['viewCount'].plot(kind='hist',bins=50,title='hello',figsize=(5,5))
# Out:
# <AxesSubplot: title={'center': 'hello'}, ylabel='Frequency'>

# %%
adf.plot(kind='scatter',x='viewCount',y='likeCount')
# Out:
# C:\Users\konst\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='viewCount', ylabel='likeCount'>

# %%
#high correlation ,more views more likes
#i can also see 2 outliers

# %%
adf[adf['likeCount']>10000000]
# Out:
#                                                        title  \
# id
# 0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
#
#                                                    description  \
# id
# 0e3GPea1Tyg  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...
# 0e3GPea1Tyg  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...
# dBxOYE2j55U  WHAT IS UP LOGANG, MAKE SURE YOU LIKE THE VIDE...
#
#                            publishTime     kind_stats  duration_seconds  \
# id
# 0e3GPea1Tyg  2021-11-24 21:00:01+00:00  youtube#video              1542
# 0e3GPea1Tyg  2021-11-24 21:00:01+00:00  youtube#video              1542
# dBxOYE2j55U  2019-01-16 22:05:01+00:00  youtube#video               791
#
#                viewCount   likeCount  commentCount      rate
# id
# 0e3GPea1Tyg  178763228.0  12250732.0      571946.0  0.068530
# ...

# %%
adf.query('likeCount>10000000')#same with query
# Out:
#                                                        title  \
# id
# 0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
#
#                                                    description  \
# id
# 0e3GPea1Tyg  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...
# 0e3GPea1Tyg  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...
# dBxOYE2j55U  WHAT IS UP LOGANG, MAKE SURE YOU LIKE THE VIDE...
#
#                            publishTime     kind_stats  duration_seconds  \
# id
# 0e3GPea1Tyg  2021-11-24 21:00:01+00:00  youtube#video              1542
# 0e3GPea1Tyg  2021-11-24 21:00:01+00:00  youtube#video              1542
# dBxOYE2j55U  2019-01-16 22:05:01+00:00  youtube#video               791
#
#                viewCount   likeCount  commentCount      rate
# id
# 0e3GPea1Tyg  178763228.0  12250732.0      571946.0  0.068530
# ...

# %%
adf.to_csv('hello.csv')
adf.to_csv('helloWithoutIndex.csv',index=False)
